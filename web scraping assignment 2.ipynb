# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url= "https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&p%5B%5D=facets.brand%255B%255D%3DLenovo&p%5B%5D=facets.type%255B%255D%3DGaming%2BLaptop&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkxlbm92byBHYW1pbmcgTGFwdG9wcyJdLCJ2YWx1ZVR5cGUiOiJNVUxUSV9WQUxVRUQifX19fX0%3D&wid=4.productCard.PMU_V2_2"

# %%
page=requests.get(url)
#page
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(page.text, 'html.parser')
#print(soup.prettify)

# %%
body=soup.find('div')
#print(body)

# %%
lists=body.find_all('div',class_='_3pLy-c row')
print(len(lists))
# Out:
# 24

# %%
data= []

for mobile in lists:
    name=mobile.find('div',class_='_4rR01T').get_text(strip=True).split('-')[0]
    disc=mobile.find('ul',class_='_1xgFaf').get_text(strip=True)
    price=mobile.find('div',class_='_30jeq3 _1_WHN1').get_text(strip=True)
    info=(name,disc,price)
    data.append(info)
    #print(data)

# %%
sale_mobile = pd.DataFrame(data, columns=['Name', 'description', 'Price'])
sale_mobile
# Out:
#                                                  Name  \
# 0                    Lenovo IdeaPad Core i5 11th Gen
# 1    Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core AMD R5
# 2             Lenovo IdeaPad Gaming Core i5 11th Gen
# 3    Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core AMD R7
# 4               Lenovo Legion 5 Pro Core i7 12th Gen
# 5    Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core AMD R5
# 6      Lenovo IdeaPad Gaming Ryzen 7 Octa Core 5800H
# 7   Lenovo Lenovo IdeaPad Gaming 3 Intel Core i5 1...
# 8           Lenovo IdeaPad Gaming 3 Core i7 12th Gen
# 9           Lenovo IdeaPad Gaming 3 Core i5 12th Gen
# 10       Lenovo Legion 5 Pro Ryzen 7 Octa Core 6800H
# 11          Lenovo IdeaPad Gaming 3 Core i5 11th Gen
# 12       Lenovo Legion 5 Pro Ryzen 7 Octa Core 6800H
# 13           Lenovo Legion 5 Ryzen 7 Octa Core AMD R7
# 14          Lenovo Yoga Slim 7 ProX Core i7 12th Gen
# 15   Lenovo IdeaPad Gaming 3 Ryzen 5 Hexa Core AMD R5
# 16       Lenovo Legion 5 Pro Ryzen 7 Octa Core 5800H
# 17                 Lenovo Legion S7 Core i7 12th Gen
# 18              Lenovo Legion 5 Pro Core i7 12th Gen
# 19            Lenovo IdeaPad Ryzen 5 Hexa Core 5600H
# 20       Lenovo Legion 5 Pro Ryzen 7 Octa Core 5800H
# 21   Lenovo Ideapad Gaming 3 Ryzen 5 Hexa Core 4600H
# 22          Lenovo IdeaPad Gaming 3 Core i5 12th Gen
# 23   Lenovo IdeaPad Gaming 3 Ryzen 7 Octa Core AMD R7
#
#                                           description      Price
# 0   Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...    ₹53,613
# 1   AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...    ₹50,990
# 2   Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...    ₹51,613
# 3   AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAM6...    ₹80,990
# 4   Intel Core i7 Processor (12th Gen)16 GB DDR5 R...  ₹1,64,990
# 5   AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAM6...    ₹68,990
# 6   AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAM6...    ₹90,990
# 7   Intel Core i5 Processor (11th Gen)16 GB DDR4 R...    ₹63,990
# 8   Intel Core i7 Processor (12th Gen)16 GB DDR4 R...  ₹1,18,990
# 9   Intel Core i5 Processor (12th Gen)16 GB DDR4 R...    ₹84,990
# 10  AMD Ryzen 7 Octa Core Processor32 GB DDR5 RAMW...  ₹1,89,990
# 11  Intel Core i5 Processor (11th Gen)8 GB DDR4 RA...    ₹64,990
# 12  AMD Ryzen 7 Octa Core Processor32 GB DDR5 RAM6...  ₹1,89,990
# 13  AMD Ryzen 7 Octa Core Processor16 GB DDR4 RAM6...  ₹1,31,990
# 14  Intel Core i7 Processor (12th Gen)16 GB LPDDR5...  ₹1,59,990
# 15  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...    ₹62,990
# 16  AMD Ryzen 7 Octa Core Processor16 GB DDR5 RAMW...  ₹1,59,990
# 17  Intel Core i7 Processor (12th Gen)8 GB DDR5 RA...  ₹1,49,990
# 18  Intel Core i7 Processor (12th Gen)16 GB DDR5 R...  ₹1,64,990
# 19  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAMWi...    ₹49,990
# 20  AMD Ryzen 7 Octa Core Processor32 GB DDR4 RAMW...  ₹1,79,990
# 21  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...    ₹62,490
# 22  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...    ₹84,990
# 23  AMD Ryzen 7 Octa Core Processor8 GB DDR4 RAM64...    ₹76,990

# %%
sale_mobile.to_excel('flipcart scarping.xlsx',index=False)
